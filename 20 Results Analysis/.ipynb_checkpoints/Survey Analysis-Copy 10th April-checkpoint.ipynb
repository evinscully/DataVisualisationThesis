# %% [markdown]
# Name: Evin Scully
#
# Student Number: 12399266

# %% [markdown]
# # Contents of code
# 1. Pre Analysis/ setup
#     1. Importing and Tidying Data
#     2. Reshaping Data
#     3. Describe Data
# 2. Composition of sample
#     1. Composition of sample
#     2. Comparison to Irish population
# 3. Main Analysis
#     1. Check consistency across blocks
#     2. Investigate comparison of Total Error to metadata
#     3. Scenario question results
#     4. Investigate how each graph performed
#     5. Pie Charts
# ***

# %% [markdown]
# # 1. Pre Analysis/ setup

# %% [markdown]
# To begin, the correct packages must be installed

# %%
# %matplotlib inline
import pandas as pd
import os
import csv
from IPython.display import HTML, display
os.chdir('C:/Users/user/Google Drive/College/- Thesis/20 Results Analysis/Data')
pd.set_option('display.max_columns', None)

import numpy as np
import scipy
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(sum(map(ord, "aesthetics")))
sns.set_style('ticks')

# %% [markdown]
# ### 1.A. Importing and Tidying Data

# %% [markdown]
# First the survey responses and true values (tv) are imported from .csv files and saved as dataframes. Then the "Block" column is made and labelled appropriately.
#
# The true values are then merged with the appropriate dataframe so as to be easily comparable.

# %%
df_tv = pd.read_csv('TrueValues.csv')
df_b1 = pd.read_csv('Block 1 Responses.csv')
df_b2 = pd.read_csv('Block 2 Responses.csv')
df_b3 = pd.read_csv('Block 3 Responses.csv')
df_b4 = pd.read_csv('Block 4 Responses.csv')

df_b1['Block']=1
df_b2['Block']=2
df_b3['Block']=3
df_b4['Block']=4

df_b1 = pd.merge(df_b1, df_tv, how='left', left_on='Block', right_on='block')
df_b2 = pd.merge(df_b2, df_tv, how='left', left_on='Block', right_on='block')
df_b3 = pd.merge(df_b3, df_tv, how='left', left_on='Block', right_on='block')
df_b4 = pd.merge(df_b4, df_tv, how='left', left_on='Block', right_on='block')

# %% [markdown]
# Concatenate all the datasets together

# %%
df = pd.concat([df_b1, df_b2, df_b3, df_b4])
df = df.reset_index(drop=True)

# %% [markdown]
# Remove the example questions

# %%
df.drop(['exp1','exp2','exp3','exp4'], axis=1, inplace=True)

# %% [markdown]
# Convert the datetime column from a string into a date

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %% [markdown]
# Calculate Errors (_er) as in percentage points and calculate absolute error, abs_er
#
# Note how the angle charts are divided by 3.60 to convert the angles into percentage points.

# %%
df['pie_er'] = (df.pie - df.pie_tv)
df['donut_er'] = (df.donut - df.donut_tv)
df['treemap_er'] = (df.treemap - df.treemap_tv)
df['bar_er'] = (df.bar - df.bar_tv)
df['stacked_er'] = (df.stacked - df.stacked_tv)
df['funnel_er'] = (df.funnel - df.funnel_tv)
# divided by 3.60 to convert the angles into percentage points
df['angle1_er'] = (df.angle1/3.60 - df.angle1_tv)
df['angle2_er'] = (df.angle2/3.60 - df.angle2_tv)
df['arc1_er'] = (df.arc1 - df.arc1_tv)
df['arc2_er'] = (df.arc2 - df.arc2_tv)
df['area1_er'] = (df.area1- df.area1_tv)
df['area2_er'] = (df.area2 - df.area2_tv)

df['pie_abs_er'] = abs(df.pie - df.pie_tv)
df['donut_abs_er'] = abs(df.donut - df.donut_tv)
df['treemap_abs_er'] = abs(df.treemap - df.treemap_tv)
df['bar_abs_er'] = abs(df.bar - df.bar_tv)
df['stacked_abs_er'] = abs(df.stacked - df.stacked_tv)
df['funnel_abs_er'] = abs(df.funnel - df.funnel_tv)
# divided by 3.60 to convert the angles into percentage points
df['angle1_abs_er'] = abs(df.angle1/3.60 - df.angle1_tv)
df['angle2_abs_er'] = abs(df.angle2/3.60 - df.angle2_tv)
df['arc1_abs_er'] = abs(df.arc1 - df.arc1_tv)
df['arc2_abs_er'] = abs(df.arc2 - df.arc2_tv)
df['area1_abs_er'] = abs(df.area1- df.area1_tv)
df['area2_abs_er'] = abs(df.area2 - df.area2_tv)

# %% [markdown]
# View a list of all the column names

# %%
list(df)
# Out:
# ['timestamp',
#  'age',
#  'gender',
#  'education',
#  'device',
#  'eyecolour',
#  'colourblind',
#  'learntype',
#  'vistools',
#  'scenario1',
#  'scenario2',
#  'scenario3',
#  'scenario4',
#  'pie',
#  'donut',
#  'treemap',
#  'bar',
#  'stacked',
#  'funnel',
#  'angle1',
#  'angle2',
#  'arc1',
#  'arc2',
#  'area1',
#  'area2',
#  'comments',
#  'confidence',
#  'Block',
#  'block',
#  'pie_tv',
#  'donut_tv',
#  'treemap_tv',
#  'bar_tv',
#  'stacked_tv',
#  'funnel_tv',
#  'angle1_tv',
#  'angle2_tv',
#  'arc1_tv',
#  'arc2_tv',
#  'area1_tv',
#  'area2_tv',
#  'pie_er',
#  'donut_er',
#  'treemap_er',
#  'bar_er',
#  'stacked_er',
#  'funnel_er',
#  'angle1_er',
#  'angle2_er',
#  'arc1_er',
#  'arc2_er',
#  'area1_er',
#  'area2_er']

# %% [markdown]
# Create a Total Error field, which is the sum of the absolute value for each error.

# %%
# They are first set to 0 so that if the cell is reran it doesn't sum it again
df['Total_Error'] = 0


# iloc 41-53 refers to columns number 41-53, which are the _er columns made above
for i in range(41,53):
    df['Total_Error'] += abs(df.iloc[:, i])

# %%
# To check  that the iloc numbers are correct they are printed here:
print(df.iloc[0,41:53])
# Out:
# pie_er            0.8
# donut_er          3.7
# treemap_er        8.1
# bar_er              3
# stacked_er        3.6
# funnel_er         7.2
# angle1_er     2.92222
# angle2_er         1.5
# arc1_er           0.8
# arc2_er           3.6
# area1_er          6.9
# area2_er            3
# Name: 0, dtype: object

# %% [markdown]
# Tidying some categorical outliers

# %%
df['education'].replace(['GCSE ?', 'ACA '], np.NaN, inplace=True)
df['education'] = df['education'].astype(pd.api.types.CategoricalDtype(categories = 
                                                                       ["Leaving Certificate", "Ordinary Bachelor Degree", "Honours Bachelor Degree", "Masters Degree", "Doctoral Degree", ""]
                                                                      ,ordered=True))

df['gender'].replace(['Non binary ', 'None'], 'Other', inplace=True)
df['eyecolour'].replace(['Bluey greeny yellowy grey', 'Greyish blue ', 'Hazel', 'grey',
 'White around the edges, black in the middle', 'blue-green', 'hazel'], 'Other', inplace=True)
set(df.gender)
set(df.eyecolour)
# Out:
# {'Blue', 'Brown', 'Green', 'Grey', 'Other'}

# %% [markdown]
# Trimming Data

# %%
print('This is the amount of observations before trimming:',len(df))

high = 0.875
low = 0.125

upperq = df['Total_Error'].quantile(high)
lowerq = df['Total_Error'].quantile(low)

# tdf = Trimmed Data Frame
df['Trimmed'] = df['Total_Error'].between(lowerq,upperq)
tdf = df[df['Trimmed']]

trimDictionary = {True: 'Kept', False: 'Trimmed'}
df['Trimmed'] = df['Trimmed'].replace(trimDictionary)

print(upperq)
print(lowerq)


print('This is the amount of observations after trimming:',len(tdf))
# Out:
# This is the amount of observations before trimming: 138
# 80.52916666666668
# 26.03819444444444
# This is the amount of observations after trimming: 102

# %%
df
# Out:
#               timestamp   age  gender                 education  \
# 0   2018-02-19 17:08:00  24.0    Male   Honours Bachelor Degree
# 1   2018-02-19 19:59:00  23.0  Female            Masters Degree
# 2   2018-02-19 20:03:00  24.0    Male   Honours Bachelor Degree
# 3   2018-02-19 20:21:00  24.0    Male   Honours Bachelor Degree
# 4   2018-02-19 20:43:00  25.0  Female   Honours Bachelor Degree
# 5   2018-02-19 20:47:00  22.0    Male            Masters Degree
# 6   2018-02-19 20:55:00  23.0    Male            Masters Degree
# 7   2018-02-19 21:24:00  27.0    Male   Honours Bachelor Degree
# 8   2018-02-19 21:34:00  26.0    Male            Masters Degree
# 9   2018-02-19 22:14:00  24.0  Female   Honours Bachelor Degree
# 10  2018-02-19 22:27:00  24.0    Male   Honours Bachelor Degree
# 11  2018-02-19 22:30:00  26.0    Male       Leaving Certificate
# 12  2018-02-19 22:39:00  24.0    Male            Masters Degree
# 13  2018-02-19 22:47:00  20.0  Female   Honours Bachelor Degree
# 14  2018-02-19 22:52:00  24.0    Male  Ordinary Bachelor Degree
# 15  2018-02-19 22:53:00  23.0  Female   Honours Bachelor Degree
# 16  2018-02-19 23:01:00  21.0   Other   Honours Bachelor Degree
# 17  2018-02-19 23:37:00  22.0    Male   Honours Bachelor Degree
# 18  2018-02-20 01:07:00  24.0  Female            Masters Degree
# 19  2018-02-20 05:52:00  24.0    Male   Honours Bachelor Degree
# 20  2018-02-20 07:13:00  24.0  Female            Masters Degree
# 21  2018-02-20 12:48:00   NaN    Male            Masters Degree
# 22  2018-02-20 14:44:00  24.0    Male   Honours Bachelor Degree
# 23  2018-02-20 15:23:00  22.0    Male   Honours Bachelor Degree
# 24  2018-02-20 17:16:00  24.0    Male   Honours Bachelor Degree
# 25  2018-02-20 20:57:00  25.0  Female            Masters Degree
# 26  2018-02-20 22:54:00  24.0  Female   Honours Bachelor Degree
# 27  2018-02-21 00:24:00  24.0  Female   Honours Bachelor Degree
# 28  2018-02-21 07:24:00  27.0    Male   Honours Bachelor Degree
# 29  2018-02-21 12:52:00  26.0    Male            Masters Degree
# ..                  ...   ...     ...                       ...
# 108 2018-02-19 19:56:48  24.0    Male   Honours Bachelor Degree
# 109 2018-02-19 20:03:12  25.0    Male       Leaving Certificate
# 110 2018-02-19 20:05:24  24.0  Female   Honours Bachelor Degree
# 111 2018-02-19 20:50:30  24.0    Male   Honours Bachelor Degree
# 112 2018-02-19 21:05:19  24.0    Male   Honours Bachelor Degree
# 118             Mobile Phone     Brown
# 119             Mobile Phone     Other
# 120             Mobile Phone      Blue
# 121             Mobile Phone     Green
# 122             Mobile Phone     Other
# 123             Mobile Phone     Other
# 124  Desktop/Laptop Computer      Blue
# 125  Desktop/Laptop Computer      Blue
# 126             Mobile Phone      Blue
# 127             Mobile Phone     Green
# 128             Mobile Phone     Brown
# 129  Desktop/Laptop Computer      Blue
# 130             Mobile Phone     Brown
# 131  Desktop/Laptop Computer      Blue
# 132  Desktop/Laptop Computer     Brown
# 133             Mobile Phone     Brown
# 134             Mobile Phone      Blue
# 135  Desktop/Laptop Computer      Blue
# 136             Mobile Phone      Grey
# 137  Desktop/Laptop Computer     Brown
#
#                                            colourblind  learntype  \
# 0                                                   No          2
# 1                                                   No          3
# 2                                                   No          3
# 3                                                   No          2
# 4                                                   No          2
# 5                                                   No          3
# 6                                                   No          3
# 7                                                   No          3
# 8                                                   No          2
# 9                                                   No          2
# 10   Deuteranomalous (reduced sensitivity to green ...          3
# 11                                                  No          1
# 12                                                  No          3
# 13                                                  No          3
# 14                                                  No          2
# 15                                                  No          3
# 16                                                  No          3
# 17                                                  No          3
# 18                                                  No          3
# 19                                                  No          3
# 20                                                  No          2
# 21                                                  No          2
# 22                                                  No          2
# 23                                                  No          2
# 24                                                  No          3
# 25                                                  No          2
# 26                                                  No          2
# 27                                                  No          3
# 28                                                  No          3
# 29                                                  No          3
# ..                                                 ...        ...
# 108                                                 No          3
# 109                                                 No          2
# 110                                                 No          2
# 111                                                 No          1
# 112                                                 No          3
# 113                                                 No          3
# 114                                                 No          3
# 115                                                 No          2
# 116                                                 No          2
# 117                                                 No          2
# 118                                                 No          2
# 119                                                 No          2
# 120                                                 No          3
# 121                                                 No          2
# 122                                                 No          2
# 123                                                 No          3
# 124                                                 No          3
# 125                 Deuteranopes (red-green blindness)          2
# 126                                                 No          1
# 127                                                 No          3
# 128                                                 No          2
# 129                                                 No          3
# 130                                                 No          2
# 131                                                 No          2
# 132                                                 No          3
# 133                                                 No          3
# 134                                                 No          1
# 135                                                 No          2
# 136                                                 No          2
# 137                                                 No          3
#
#                                               vistools scenario1 scenario2  \
# 0                                                  NaN  Option 2  Option 2
# 1                                    Excel, Powerpoint  Option 2  Option 2
# 2                                     Excel, R, MATLAB  Option 2  Option 2
# 3                                                    R  Option 1  Option 1
# 4                                                  NaN  Option 2  Option 2
# 5                              Excel, Powerpoint, SCSS  Option 2  Option 2
# 6                                    Excel, Powerpoint  Option 2  Option 2
# 7                                    Adobe Illustrator  Option 2  Option 2
# 8                    Excel, Powerpoint, Python, MATLAB  Option 2  Option 2
# 9                                           Powerpoint  Option 2  Option 2
# 10                           Excel, Powerpoint, MATLAB  Option 2  Option 2
# 11                                                 NaN  Option 2  Option 2
# 12                                               Excel  Option 2  Option 2
# 13                                                 NaN  Option 2  Option 1
# 14                                                 NaN  Option 2  Option 2
# 15                                   Adobe Illustrator  Option 2  Option 2
# 16                                                 NaN  Option 2  Option 2
# 17                           Excel, Powerpoint, Python  Option 1  Option 2
# 18                                   Excel, Powerpoint  Option 2  Option 2
# 19                                                 NaN  Option 2  Option 2
# 20                                          Powerpoint  Option 2  Option 2
# 21                                          Powerpoint  Option 2  Option 2
# 22   Excel, Powerpoint, Numbers, Pages, GoodNotes4,...  Option 2  Option 2
# 23                                   Excel, Powerpoint  Option 2  Option 2
# 24                                                 NaN  Option 2  Option 2
# 25                                          Powerpoint  Option 2  Option 2
# 26                                                 NaN  Option 2  Option 1
# 27                                          Powerpoint  Option 2  Option 2
# 28                                               Visio  Option 2  Option 2
# 29                        Excel, Python, R, MATLAB, D3  Option 2  Option 2
# ..                                                 ...       ...       ...
# 108                         Powerpoint, Python, MATLAB  Option 2  Option 2
# 109                                                NaN  Option 2  Option 2
# 110                                              Excel  Option 2  Option 2
# 111                                                NaN  Option 2  Option 2
# 112                      Powerpoint, Adobe Illustrator  Option 2  Option 2
# 113                                                NaN  Option 2  Option 2
# 114                                             Python  Option 2  Option 1
# 115                                              Paint  Option 2  Option 2
# 116                                         Powerpoint  Option 2  Option 2
# 117                                  Excel, Powerpoint  Option 2  Option 2
# 118                                  Excel, Powerpoint  Option 2  Option 2
# 119                                  Excel, Powerpoint  Option 2  Option 2
# 120                           Excel, Powerpoint, Canva  Option 2  Option 2
# 121                                         Powerpoint  Option 2  Option 2
# 122                                                NaN  Option 2  Option 1
# 123                          Excel, Powerpoint, Origin  Option 2  Option 2
# 124                                                  R  Option 2  Option 1
# 125                                                NaN  Option 2  Option 2
# 126                                         Powerpoint  Option 2  Option 2
# 127                                 Powerpoint, Python  Option 2  Option 2
# 128                                                NaN  Option 2  Option 2
# 129                                         Powerpoint  Option 2  Option 2
# 130                                                NaN  Option 2  Option 2
# 131                                                NaN  Option 2  Option 2
# 132                              Excel, Graphpad Prism  Option 2  Option 2
# 133                        Excel, Powerpoint, Power BI  Option 2  Option 1
# 134                                         Powerpoint  Option 2  Option 2
# 135                                              Excel  Option 2  Option 2
# 136                                         Powerpoint  Option 2  Option 2
# 137                  Excel, Powerpoint, Python, MATLAB  Option 2  Option 2
#
#     scenario3 scenario4        pie  donut    treemap  bar  stacked   funnel  \
# 0    Option 2  Option 1  17.000000  42.00  18.000000    7    35.00  15.0000
# 1    Option 2  Option 3  28.000000  40.00  42.000000   12    35.00  20.0000
# 2    Option 2  Option 3  15.000000  40.00  21.000000    8    30.00  20.0000
# 3    Option 1  Option 3  20.000000  38.00  20.000000   10    30.00  20.0000
# 4    Option 1  Option 1  60.000000  40.00  26.000000   10    38.00  20.0000
# 5    Option 2  Option 3  20.000000  37.00  35.000000   10    40.00  22.0000
# 6    Option 2  Option 3  15.000000  40.00  25.000000   10    50.00  25.0000
# 7    Option 2  Option 3  20.000000  33.00  30.000000   10    40.00  20.0000
# 8    Option 2  Option 3  19.000000  40.00  25.000000   10    40.00  20.0000
# 9    Option 1  Option 3  20.000000  35.00  25.000000   10    25.00  15.0000
# 10   Option 2  Option 3  20.000000  40.00  35.000000   10    40.00  20.0000
# 11   Option 2  Option 2  39.000000  40.00  25.000000    5    33.00  20.0000
# 117    45.0   120.0  15.000  25.00   33.3  50.000000
# 118    40.0   160.0  10.000  25.00   25.0  50.000000
# 119    70.0   120.0  10.000  20.00   30.0  50.000000
# 120    45.0   120.0  10.000  25.00   25.0  49.000000
# 121    60.0   150.0  10.000  25.00   35.0  50.000000
# 122    80.0   135.0  10.000  25.00   35.0  48.000000
# 123    60.0   120.0  12.500  25.00   33.0  50.000000
# 124    18.0   125.0   9.000  25.00   34.0  48.000000
# 125    60.0   120.0  10.000  25.00   33.0  50.000000
# 126    70.0   135.0  20.000  75.00   33.3  50.000000
# 127    83.0   125.0  14.000  27.00   33.0  45.000000
# 128    35.0   135.0   7.000  25.00   33.0  50.000000
# 129    60.0   135.0  10.000  25.00   35.0  47.000000
# 130    75.0   140.0  10.000  30.00   25.0  48.000000
# 131    50.0   135.0  10.000  25.00   37.0  45.000000
# 132    70.0   120.0  20.000  35.00   35.0  45.000000
# 133    60.0   135.0  15.000  90.00   25.0  50.000000
# 134    60.0   120.0  15.000  30.00   40.0  45.000000
# 135    75.0   135.0   7.500  25.00   30.0  50.000000
# 136    70.0   120.0  10.000  25.00   20.0  40.000000
# 137    70.0   110.0  10.000  30.00   30.0  50.000000
#
#                                               comments  confidence  Block  \
# 0                                                  NaN         3.0      1
# 1                                                  NaN         3.0      1
# 2    I’m seriously interested in these results. The...         3.0      1
# 3    The 15 seconds gave me all the time I needed h...         4.0      1
# 4                                                  NaN         4.0      1
# 5                                                  NaN         4.0      1
# 6                                                  NaN         3.0      1
# 7                                      I love you Evin         4.0      1
# 8                           Really interesting topic!          4.0      1
# 9    For the question on toothbrush sales the figur...         3.0      1
# 10                                                 NaN         3.0      1
# 11   That was class craic! A real workout for the n...         3.0      1
# 12                                                 NaN         4.0      1
# 13             that was hard. clearly explained though         5.0      1
# 14                                                 NaN         4.0      1
# 15                                                 NaN         2.0      1
# 16                                                 NaN         3.0      1
# 17                                                 NaN         2.0      1
# 18                                                 NaN         4.0      1
# 19   This was extremely interesting. I'd love to be...         4.0      1
# 20                                                 NaN         3.0      1
# 21                                                 NaN         4.0      1
# 22                         Fuckn, graphs are hard man          2.0      1
# 23                                                 NaN         3.0      1
# 24                                                 NaN         3.0      1
# 25                                                 NaN         2.0      1
# 26                                                 NaN         3.0      1
# 27                                                 NaN         3.0      1
# 28                                                 NaN         4.0      1
# 29   Interested in your thesis.  Share results when...         3.0      1
# ..                                                 ...         ...    ...
# 108  Difficult to tell the angles/comparisons witho...         3.0      4
# 109                                                NaN         2.0      4
# 110                                                NaN         3.0      4
# 111                                                NaN         2.0      4
# 112                        I’m too dyspraxic for this          1.0      4
# 113                                                NaN         1.0      4
# 114                                                NaN         4.0      4
# 115                                     V interesting!         3.0      4
# 116                                                NaN         3.0      4
# 117                                                NaN         3.0      4
# 118                                                Nah         3.0      4
# 119                                        Good luck!          4.0      4
# 120  That one with the orange and blue circle reall...         2.0      4
# 121                                                NaN         4.0      4
# 122                                                NaN         4.0      4
# 123                               Fun figuring it out!         4.0      4
# 124                                                NaN         4.0      4
# 125                                                NaN         3.0      4
# 126                                                NaN         2.0      4
# 127                                                NaN         4.0      4
# 128                                                NaN         4.0      4
# 129  Nice survey my brother, I hope your thesis goe...         5.0      4
# 130                                                NaN         2.0      4
# 131                                                NaN         3.0      4
# 132                                                NaN         3.0      4
# 133                                                NaN         NaN      4
# 134                                                NaN         4.0      4
# 135                                                NaN         4.0      4
# 136                                                NaN         5.0      4
# 137                                                NaN         3.0      4
#
#      block  pie_tv  donut_tv  treemap_tv  bar_tv  stacked_tv  funnel_tv  \
# 0        1    17.8      38.3        26.1    10.0        38.6       22.2
# 1        1    17.8      38.3        26.1    10.0        38.6       22.2
# 2        1    17.8      38.3        26.1    10.0        38.6       22.2
# 3        1    17.8      38.3        26.1    10.0        38.6       22.2
# 4        1    17.8      38.3        26.1    10.0        38.6       22.2
# 5        1    17.8      38.3        26.1    10.0        38.6       22.2
# 6        1    17.8      38.3        26.1    10.0        38.6       22.2
# 7        1    17.8      38.3        26.1    10.0        38.6       22.2
# 8        1    17.8      38.3        26.1    10.0        38.6       22.2
# 9        1    17.8      38.3        26.1    10.0        38.6       22.2
# 10       1    17.8      38.3        26.1    10.0        38.6       22.2
# 11       1    17.8      38.3        26.1    10.0        38.6       22.2
# 12       1    17.8      38.3        26.1    10.0        38.6       22.2
# 13       1    17.8      38.3        26.1    10.0        38.6       22.2
# 14       1    17.8      38.3        26.1    10.0        38.6       22.2
# 15       1    17.8      38.3        26.1    10.0        38.6       22.2
# 16       1    17.8      38.3        26.1    10.0        38.6       22.2
# 17       1    17.8      38.3        26.1    10.0        38.6       22.2
# 18       1    17.8      38.3        26.1    10.0        38.6       22.2
# 19       1    17.8      38.3        26.1    10.0        38.6       22.2
# 20       1    17.8      38.3        26.1    10.0        38.6       22.2
# 21       1    17.8      38.3        26.1    10.0        38.6       22.2
# 22       1    17.8      38.3        26.1    10.0        38.6       22.2
# 23       1    17.8      38.3        26.1    10.0        38.6       22.2
# 24       1    17.8      38.3        26.1    10.0        38.6       22.2
# 25       1    17.8      38.3        26.1    10.0        38.6       22.2
# 26       1    17.8      38.3        26.1    10.0        38.6       22.2
# 27       1    17.8      38.3        26.1    10.0        38.6       22.2
# 28       1    17.8      38.3        26.1    10.0        38.6       22.2
# 29       1    17.8      38.3        26.1    10.0        38.6       22.2
# ..     ...     ...       ...         ...     ...         ...        ...
# 108      4    10.3      17.8        17.5    76.6        26.1       10.8
# 109      4    10.3      17.8        17.5    76.6        26.1       10.8
# 110      4    10.3      17.8        17.5    76.6        26.1       10.8
# 111      4    10.3      17.8        17.5    76.6        26.1       10.8
# 112      4    10.3      17.8        17.5    76.6        26.1       10.8
# 113      4    10.3      17.8        17.5    76.6        26.1       10.8
# 114      4    10.3      17.8        17.5    76.6        26.1       10.8
# 115      4    10.3      17.8        17.5    76.6        26.1       10.8
# 116      4    10.3      17.8        17.5    76.6        26.1       10.8
# 117      4    10.3      17.8        17.5    76.6        26.1       10.8
# 118      4    10.3      17.8        17.5    76.6        26.1       10.8
# 17    4.750000    5.800     8.60      11.9   2.000000    74.550000     Kept
# 18    2.666667    2.200     1.40       1.9   2.000000    27.500000     Kept
# 19    2.666667    0.800     8.60       6.9   2.000000    45.300000     Kept
# 20    4.055556    2.200     3.60       1.9   3.000000    55.555556     Kept
# 21    1.277778    2.800     0.60       3.1   1.000000    70.222222     Kept
# 22    0.111111    0.800     1.10       3.1   2.000000    25.755556  Trimmed
# 23    1.000000    9.200     1.40       1.9   2.000000    35.400000     Kept
# 24    2.666667    2.200     1.40       1.9   2.000000    20.900000  Trimmed
# 25    1.500000    2.536     1.40       1.9   2.000000    22.236000  Trimmed
# 26    2.888889   10.800     3.60      11.9   2.000000    68.288889     Kept
# 27    1.500000    2.200     5.60       1.9   2.000000    43.044444     Kept
# 28    1.500000   59.200     3.60       3.1   3.000000    91.844444  Trimmed
# 29    2.666667    7.200     1.40       1.9   2.000000    48.855556     Kept
# ..         ...      ...      ...       ...        ...          ...      ...
# 108   1.100000    1.500     1.90       5.8  18.666667    40.800000     Kept
# 109  11.400000    4.000     1.90       5.8   8.000000    93.755556  Trimmed
# 110   5.266667    1.000     8.90      10.8   3.000000    46.311111     Kept
# 111   5.266667    1.500     1.90       2.2   8.000000    39.177767     Kept
# 112  17.766667    4.000     1.90       5.8   8.000000    90.200000  Trimmed
# 113   5.266667    9.000     8.10       2.2   1.000000    68.866667     Kept
# 114   8.044444    6.000     1.90      44.2   0.000000    92.133333  Trimmed
# 115   2.488889    4.000     1.90       4.2   2.000000    45.944444     Kept
# 116   5.266667    1.000     3.10       0.8   3.000000    42.166667     Kept
# 117   5.266667    4.000     1.90       2.5   2.000000    42.266667     Kept
# 118   5.844444    1.000     1.90       5.8   2.000000    49.333333     Kept
# 119   5.266667    1.000     6.90       0.8   2.000000    33.711111     Kept
# 120   5.266667    1.000     1.90       5.8   1.000000    81.633333  Trimmed
# 121   3.066667    1.000     1.90       4.2   2.000000    22.200000  Trimmed
# 122   1.100000    1.000     1.90       4.2   0.000000    25.522222  Trimmed
# 123   5.266667    1.500     1.90       2.2   2.000000    22.200000  Trimmed
# 124   3.877778    2.000     1.90       3.2   0.000000    64.977778     Kept
# 125   5.266667    1.000     1.90       2.2   2.000000    30.800000     Kept
# 126   1.100000    9.000    48.10       2.5   2.000000    74.244444     Kept
# 127   3.877778    3.000     0.10       2.2   3.000000    60.933333     Kept
# 128   1.100000    4.000     1.90       2.2   2.000000    37.577778     Kept
# 129   1.100000    1.000     1.90       4.2   1.000000    32.433333     Kept
# 130   0.288889    1.000     3.10       5.8   0.000000    26.822222     Kept
# 131   1.100000    1.000     1.90       6.2   3.000000    26.011111  Trimmed
# 132   5.266667    9.000     8.10       4.2   3.000000    70.511111     Kept
# 133   1.100000    4.000    63.10       5.8   2.000000   136.833333  Trimmed
# 134   5.266667    4.000     3.10       9.2   3.000000    50.200000     Kept
# 135   1.100000    3.500     1.90       0.8   2.000000    24.063333  Trimmed
# 136   5.266667    1.000     1.90      10.8   8.000000    48.511111     Kept
# 137   8.044444    1.000     3.10       0.8   2.000000    86.348889  Trimmed
#
# [138 rows x 55 columns]

# %% [markdown]
# ### 1.B. Reshaping Data

# %% [markdown]
# The dataset will now be unpivoted into a "long" format. This means that each observation is not on a per user basis, but on a *per answer* basis. This is necessary to make have the data sub divided into smaller slices and make comparisons between each chart.

# %%
df_long = pd.melt(tdf, id_vars=['timestamp', 'Block', 'age', 'gender', 'education', 'device', 'eyecolour', 'colourblind', 'learntype', 'vistools'],\
                   value_vars=['pie_er', 'donut_er', 'treemap_er', 'bar_er', 'stacked_er', 'funnel_er', 'angle1_er', 'angle2_er', 'arc1_er', 'arc2_er', 'area1_er', 'area2_er',],\
                   var_name='charttype', value_name='error')

# Remove the _er suffix at the end of charttype
df_long['charttype'] = df_long['charttype'].str[:-3]

#Create a label called "chart_id" to merge when combined with true values later
df_long['chart_id'] = df_long['charttype'] + df_long['Block'].apply(str)

#Combine the angle1 & angle 2 into one angle chart type. Do the same for arc and angle.
df_long['charttype'].replace(to_replace=['angle1', 'angle2', 'arc1', 'arc2', 'area1', 'area2'],
                             value=['angle','angle','arc','arc','area','area'],
                             method='string', inplace=True)

print('Here is a list of the chartypes :',set(df_long.charttype))
# Out:
# Here is a list of the chartypes : {'donut', 'stacked', 'angle', 'arc', 'treemap', 'pie', 'area', 'bar', 'funnel'}

# %% [markdown]
# Create longform of true values (tv) and merge it with long form of the dataframe

# %%
df_tv_long = pd.melt(df_tv, id_vars=['block'],
                     value_vars=['pie_tv','donut_tv','treemap_tv','bar_tv','stacked_tv','funnel_tv','angle1_tv','angle2_tv','arc1_tv','arc2_tv','area1_tv','area2_tv'],
                     var_name='tvcharttype', value_name='trueValue')

df_tv_long['tvcharttype'] = df_tv_long['tvcharttype'].str[:-3] # Remove the three letter suffix
df_tv_long['chart_id'] = df_tv_long['tvcharttype'] + df_tv_long['block'].apply(str) # Add the Block number to the end
df_tv_long.drop('block', axis=1, inplace=True)

df_long = pd.merge(df_long,df_tv_long, on='chart_id')

# %%
df_long = df_long[df_long['error']<25]

# %% [markdown]
# Combine all the comments into one subset and export them as a .csv file for easy reading

# %%
# subset of comments
comments = df.comments[pd.notnull(df['comments'])]
comments.to_csv('comments.csv')










#Delete this?
#pd.options.display.max_colwidth = 100

# %% [markdown]
# ### 1.C. Describe Data

# %% [markdown]
# How many fields were left blank?

# %%
def num_missing(x):
  return sum(x.isnull())

#Applying per column:
print ("Amount participants left blank:")
print (df.apply(num_missing, axis=0).head(9)) #axis=0 defines that function is to be applied on each column
# Out:
# Amount participants left blank:
# timestamp       0
# age             9
# gender          1
# education       3
# device          0
# eyecolour       0
# colourblind     0
# learntype       0
# vistools       32
# dtype: int64

# %% [markdown]
# Summary statistics

# %%
df_long.describe()
# Out:
#              Block          age    learntype        error    trueValue
# count  1213.000000  1120.000000  1213.000000  1213.000000  1213.000000
# mean      2.391591    25.256250     2.303380     3.642165    29.954823
# std       1.078210     3.624642     0.682378     3.619983    16.243746
# min       1.000000    20.000000     1.000000     0.000000     5.000000
# 25%       1.000000    23.000000     2.000000     1.400000    17.800000
# 75%     48.000000   30.800000   48.000000   26.900000   48.000000    3.100000
# max     48.000000   30.800000   48.000000   30.800000   48.000000   47.200000
#
#          donut_er  treemap_er      bar_er  stacked_er   funnel_er   angle1_er  \
# count  102.000000  102.000000  102.000000  102.000000  102.000000  102.000000
# mean     3.322549    6.343431    3.550980    3.767647    4.393246    4.284695
# std      4.895419    7.023552    3.059857    3.966298    4.722198    4.000759
# min      0.000000    0.000000    0.000000    0.000000    0.200000    0.244444
# 25%      0.300000    1.400000    2.000000    1.100000    2.200000    1.533333
# 50%      1.850000    3.600000    2.800000    2.000000    3.900000    3.022222
# 75%      3.925000    7.500000    5.000000    5.300000    5.300000    5.700000
# max     29.700000   31.400000   16.600000   21.300000   34.200000   26.100000
#
#         angle2_er     arc1_er     arc2_er    area1_er    area2_er  Total_Error
# count  102.000000  102.000000  102.000000  102.000000  102.000000   102.000000
# mean     2.299346    3.420588    4.045098    3.880392    3.207516    46.940653
# std      2.318643    3.183259    5.264784    2.846921    3.012288    14.283584
# min      0.055556    0.200000    0.000000    0.100000    0.000000    26.227778
# 25%      0.777778    1.050000    1.900000    1.900000    1.400000    35.600000
# 50%      1.344444    2.200000    2.000000    3.150000    2.000000    44.311111
# 75%      2.833333    4.000000    5.600000    5.800000    3.600000    55.044444
# max     13.011111   20.000000   48.100000   11.900000   18.666667    78.633333

# %% [markdown]
# # 2. Composition of sample

# %% [markdown]
# ### 2.A. Composition of sample

# %%
g = sns.distplot(df.age[df.age.notnull()], rug=True)
g.set(xlabel='Age', ylabel='Percentage of Participants')
sns.despine()


plt.savefig('../output/02age.png', dpi = 300)

# %%
g = sns.countplot('gender', data=df)
g.set(xlabel='Gender', ylabel='Number of Participants')
plt.xticks(rotation=60)
sns.despine()


plt.savefig('../output/02gender.png', dpi = 300)

# %%
g = sns.countplot('education', data=df)
g.set(xlabel='Education', ylabel='Number of Participants')
plt.xticks(rotation=60)
sns.despine()

plt.savefig('../output/02education.png', dpi = 300)

# %%
g = sns.countplot('device', data=df)
g.set(xlabel='Device used', ylabel='Number of Participants')
plt.xticks(rotation=0)
sns.despine()

plt.savefig('../output/02device.png', dpi = 300)

# %%
cb = 100*float('%.4f'%(sum(df.colourblind!='No')/sum(df.colourblind.notnull())))

print(cb,'% of participants were colourlbind')
# Out:
# 3.62 % of participants were colourlbind

# %%
g = sns.countplot('learntype', data=df)
g.set(xlabel='Learn Type', ylabel='Number of Participants')
sns.despine()

# %%
vistools = pd.DataFrame(df.vistools[df.vistools.notnull()].str.split(pat=',', expand=True))
vistools = pd.melt(vistools, value_name='tool')
vistools = vistools.drop(['variable'], axis=1)
vistools = vistools.dropna()
vistools['tool'] = vistools['tool'].str.strip()
minority_tools=vistools['tool'].value_counts()[vistools['tool'].value_counts() < 2].index.values
vistools['tool'].replace(minority_tools, 'Other', inplace=True)


g = sns.countplot(x = 'tool', data = vistools, color="#4c72b0",
              order = ['Powerpoint', 'Excel', 'Python', 'MATLAB', 'Adobe Illustrator',
       'R', 'Tableau', 'D3', 'Power BI', 'Canva', 'Other'])
g.set(xlabel='Visualisation Tool', ylabel='Number of Participants')
plt.xticks(rotation=60)
display(minority_tools)
sns.despine()

plt.savefig('../output/02tools.png', dpi = 300)
# Out:
# array(['SPSS', 'Paper', 'Numbers', 'Photoshop', 'GoodNotes4', 'AutoCAD',
#        'Origin', 'Visio', 'SAP Predictive Analytics', 'Prezi',
#        'Osisoft pi', 'Keynote - Mac', 'ChemDraw (similar)', 'SCSS',
#        'Pages', 'Gaussian (computational chemistry)', 'SAP Lumira',
#        'Procreate', 'Lumion', 'Qlik view / Qlik Sense', 'Paint',
#        'Graphpad Prism'], dtype=object)

# %% [markdown]
# ### 2.B. Comparison to Irish population

# %% [markdown]
# Read in census data and fit survey responses to the same format

# %%
sex = pd.read_csv('censusData/sex.csv')
edu = pd.read_csv('censusData/education.csv')
age = pd.read_csv('censusData/age.csv')

samplesex = pd.DataFrame(df['gender'].value_counts()/len(df.gender[pd.notnull(df.gender)]))
samplesex.reset_index(inplace = True)
samplesex.drop([2], inplace=True)

sampleedu = pd.DataFrame(df['education'].value_counts()/len(df.education[pd.notnull(df.education)]))
sampleedu.reset_index(inplace = True)
sampleedu.drop([5], inplace=True)

# %% [markdown]
# It is a little more complicated to transform the survey age data becuase it must be sorted into the binned format given by the census data

# %%
# Create the bins
bins = [5, 13, 19, 25, 35, 45, 55, 65, 75]

# Create a for loop to sum up the amount of participants who fell into each bin
binnedage = []
xold = 0
for x in bins:
    binnedage.append(len(df.age[df.age > xold][df.age < x]))
    xold=x
binnedage.append(0)
    
# Convert this list into a dataframe, label the bins
binnedage = pd.DataFrame(binnedage)
binnedage.columns = ['number']
binnedage['age'] = age['age']

# and then normalise it by dividing by the people who gave their age

binnedage['percent'] = binnedage.number/len(df.age[pd.notnull(df.age)])

# %% [markdown]
# #### Visualize comparison

# %% [markdown]
# Of Education

# %%
sampleedu = sampleedu.reindex([3,2,0,1,4])
sns.set_context("talk")
g = sns.factorplot(x="education", y="index", data=sampleedu,
                   size=6, kind="bar", aspect =1, color="#4c72b0")
g.set(title='Education Level of Sample', xlabel='percentage')
plt.xlim(xmax=0.5)
g.fig.axes[0].invert_yaxis()
sns.despine(right=True, left=True)
plt.savefig('../output/02Bedu1.png', dpi = 300)


g = sns.factorplot(x="percentage", y="educationLevel", data=edu,
                   size=6, kind="bar", aspect =1, color="#4c72b0")
g.set(title='Education Level of Population')
plt.xlim(xmax=0.5)
g.fig.axes[0].invert_yaxis()
sns.despine(right=True, left=True)
plt.savefig('../output/02Bedu2.png', dpi = 300)

plt.show()

# %% [markdown]
# Of Gender

# %%
g = sns.factorplot(x="gender", y="index", data=samplesex,
                   size=6, kind="bar", aspect =1, color="#4c72b0")
plt.xlim(xmax=0.6)
g.set(title='Gender of Sample', xlabel='percentage')
g.fig.axes[0].invert_yaxis()
sns.despine(right=True, left=True)
plt.savefig('../output/02Bsex1.png', dpi = 300)

g = sns.factorplot(x="percentage", y="sex", data=sex,
                   size=6, kind="bar", aspect =1, color="#4c72b0")
plt.xlim(xmax=0.6)
g.set(title='Sex of Population ', xlabel='percentage')
g.fig.axes[0].invert_yaxis()
sns.despine(right=True, left=True)
plt.savefig('../output/02Bsex2.png', dpi = 300)

# %% [markdown]
# Of Age

# %%
g = sns.factorplot(x="percent", y="age", data=age,
                   size=6, kind="bar", color="#4c72b0", aspect =1.5)
plt.xlim(xmax=0.7)
g.set(title='Age of Population', xlabel='percentage')
g.fig.axes[0].invert_yaxis()
sns.despine(right=True, left=True)
sns.set_context("talk")
plt.savefig('../output/02Bage1.png', dpi = 300)

g = sns.factorplot(x="percent", y="age", data=binnedage,
                   size=6, kind="bar", color="#4c72b0", aspect =1.5)
plt.xlim(xmax=0.7)
g.set(title='Age of Sample', xlabel='percentage')
g.fig.axes[0].invert_yaxis()
sns.despine(right=True, left=True)
sns.set_context("talk")
plt.savefig('../output/02Bage2.png', dpi = 300)

# %% [markdown]
# # 3. Main Analysis

# %% [markdown]
# ### 3.A. Check consistency across blocks

# %%
sns.set_context("notebook")
g = sns.violinplot(x="Block", y="Total_Error", data=tdf)
g = sns.swarmplot(x="Block", y="Total_Error", data=tdf, color='k', alpha=.3)
sns.despine(left=True)
plt.ylim(ymin=0)
g.set(title='Total Error across Blocks', xlabel='Block', ylabel='Summed Error per Participant')


plt.savefig('../output/03blocking.png', dpi = 300)

# %% [markdown]
# Further investigate error across different charts on a per block basis

# %%
plotdata = df_long[df_long['charttype'].isin(['pie','donut','treemap','bar','stacked','funnel'])]

g = sns.factorplot(x="Block", y="error",
                       col="charttype",
                       col_wrap=6,
                       ci=80,
                       data=plotdata, kind='violin', #or kind='swarm'
                       size=4, aspect=0.7); # linewidth=1

plt.ylim(ymin=0)

plt.savefig('../output/03blockingpergraphtrad.png', dpi = 300)

# %%
plotdata = df_long[df_long['charttype'].isin(['arc','angle','area'])]

g = sns.factorplot(x="Block", y="error",
                       col="charttype",
                       col_wrap=6,
                       ci=80,
                       data=plotdata, kind='violin', #or kind='swarm'
                       size=4, aspect=0.7); # linewidth=1
#ax.set(ylabel='Absolute Error')

plt.ylim(ymin=0)

plt.savefig('../output/03blockingpergraphaaa.png', dpi = 300)

# %% [markdown]
# ### 3.B. Investigate comparison of Total Error to metadata

# %% [markdown]
# Look at where the trimmed datapoints lie

# %%
g=sns.swarmplot( x=[""]*len(df), y=df['Total_Error'], hue=df['Trimmed'],size=8, palette=['#4c72b0','#c44e52'])
sns.despine()
g.set(ylabel='Total Error per Participant')

plt.savefig('../output/03Btrim.png', dpi = 300)

# %%
g=sns.swarmplot(x="gender", y="Total_Error", data=tdf, dodge=True)
sns.despine()
g.set(xlabel='Gender', ylabel='Total Error per Participant')


plt.savefig('../output/03Bgender.png', dpi = 300)

# %%
g = sns.swarmplot(x="education", y="Total_Error", data= tdf, dodge=False)
plt.xticks(rotation=30)
sns.despine()
g.set(xlabel='Education Level', ylabel='Total Error per Participant')

plt.savefig('../output/03Beducation.png', dpi = 300)

# %%
g=sns.swarmplot(x="device", y="Total_Error", data=tdf, dodge=False)
# Can tilt phone
sns.despine()
g.set(xlabel='Device', ylabel='Total Error per Participant')

plt.savefig('../output/03Bdevice.png', dpi = 300)

# %%
plotdata=tdf
plotdata['creator'] = pd.notnull(plotdata['vistools'])

g = sns.violinplot(x="creator", y="Total_Error", data=plotdata)
g = sns.swarmplot(x="creator", y="Total_Error", data=plotdata, color='k', alpha=.3)

# Can tilt phone
sns.despine()
g.set(title='Created Visualisation in the past six months?', xlabel='',ylabel='Total Error per Participant')

plt.savefig('../output/03Bcreator.png', dpi = 300)

len(tdf[pd.notnull(tdf['vistools'])])
# We want to show the dots when the actual quantity in each category is important
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 77

# %%
g=sns.regplot('learntype', 'Total_Error', data=tdf, x_jitter=0.05)
sns.despine()
g.set(xlabel='Learning Type', ylabel='Total Error per Participant')

plt.savefig('../output/03Blearntype.png', dpi = 300)

# %%
g= sns.swarmplot(x="eyecolour", y="Total_Error", data=tdf, order=tdf['eyecolour'].value_counts().index)
g.set(xlabel='Eye Colour', ylabel='Total Error per Participant')

sns.despine()

# %%
g=sns.regplot('confidence', 'Total_Error', data=tdf, x_jitter=0.15, ci=0)
sns.despine()
g.set(xlabel='Confidence', ylabel='Total Error per Participant')


plt.savefig('../output/03Bconfidence.png', dpi = 300)

# %% [markdown]
# Confidence didn't appear to have much correlation with how well participants did, could there be some other factors that influence confidence?

# %%
df
# Out:
#               timestamp   age  gender                 education  \
# 0   2018-02-19 17:08:00  24.0    Male   Honours Bachelor Degree
# 1   2018-02-19 19:59:00  23.0  Female            Masters Degree
# 2   2018-02-19 20:03:00  24.0    Male   Honours Bachelor Degree
# 3   2018-02-19 20:21:00  24.0    Male   Honours Bachelor Degree
# 4   2018-02-19 20:43:00  25.0  Female   Honours Bachelor Degree
# 5   2018-02-19 20:47:00  22.0    Male            Masters Degree
# 6   2018-02-19 20:55:00  23.0    Male            Masters Degree
# 7   2018-02-19 21:24:00  27.0    Male   Honours Bachelor Degree
# 8   2018-02-19 21:34:00  26.0    Male            Masters Degree
# 9   2018-02-19 22:14:00  24.0  Female   Honours Bachelor Degree
# 10  2018-02-19 22:27:00  24.0    Male   Honours Bachelor Degree
# 11  2018-02-19 22:30:00  26.0    Male       Leaving Certificate
# 12  2018-02-19 22:39:00  24.0    Male            Masters Degree
# 13  2018-02-19 22:47:00  20.0  Female   Honours Bachelor Degree
# 14  2018-02-19 22:52:00  24.0    Male  Ordinary Bachelor Degree
# 15  2018-02-19 22:53:00  23.0  Female   Honours Bachelor Degree
# 16  2018-02-19 23:01:00  21.0   Other   Honours Bachelor Degree
# 17  2018-02-19 23:37:00  22.0    Male   Honours Bachelor Degree
# 18  2018-02-20 01:07:00  24.0  Female            Masters Degree
# 19  2018-02-20 05:52:00  24.0    Male   Honours Bachelor Degree
# 20  2018-02-20 07:13:00  24.0  Female            Masters Degree
# 21  2018-02-20 12:48:00   NaN    Male            Masters Degree
# 22  2018-02-20 14:44:00  24.0    Male   Honours Bachelor Degree
# 23  2018-02-20 15:23:00  22.0    Male   Honours Bachelor Degree
# 24  2018-02-20 17:16:00  24.0    Male   Honours Bachelor Degree
# 17   Desktop/Laptop Computer      Blue
# 18              Mobile Phone     Green
# 19              Mobile Phone     Brown
# 20              Mobile Phone      Blue
# 21   Desktop/Laptop Computer      Blue
# 22                    Tablet      Grey
# 23   Desktop/Laptop Computer      Blue
# 24              Mobile Phone     Green
# 25   Desktop/Laptop Computer      Blue
# 26              Mobile Phone      Blue
# 27              Mobile Phone      Blue
# 28              Mobile Phone      Blue
# 29              Mobile Phone     Green
# ..                       ...       ...
# 108  Desktop/Laptop Computer      Blue
# 109             Mobile Phone     Brown
# 110             Mobile Phone     Brown
# 111             Mobile Phone      Blue
# 112             Mobile Phone      Blue
# 113             Mobile Phone     Brown
# 114             Mobile Phone     Green
# 115             Mobile Phone     Green
# 116             Mobile Phone     Brown
# 117             Mobile Phone     Brown
# 118             Mobile Phone     Brown
# 119             Mobile Phone     Other
# 120             Mobile Phone      Blue
# 121             Mobile Phone     Green
# 122             Mobile Phone     Other
# 123             Mobile Phone     Other
# 124  Desktop/Laptop Computer      Blue
# 125  Desktop/Laptop Computer      Blue
# 126             Mobile Phone      Blue
# 127             Mobile Phone     Green
# 128             Mobile Phone     Brown
# 129  Desktop/Laptop Computer      Blue
# 130             Mobile Phone     Brown
# 131  Desktop/Laptop Computer      Blue
# 132  Desktop/Laptop Computer     Brown
# 133             Mobile Phone     Brown
# 134             Mobile Phone      Blue
# 135  Desktop/Laptop Computer      Blue
# 136             Mobile Phone      Grey
# 137  Desktop/Laptop Computer     Brown
#
#                                            colourblind  learntype  \
# 0                                                   No          2
# 1                                                   No          3
# 2                                                   No          3
# 3                                                   No          2
# 4                                                   No          2
# 5                                                   No          3
# 6                                                   No          3
# 7                                                   No          3
# 8                                                   No          2
# 9                                                   No          2
# 10   Deuteranomalous (reduced sensitivity to green ...          3
# 11                                                  No          1
# 12                                                  No          3
# 13                                                  No          3
# 14                                                  No          2
# 15                                                  No          3
# 16                                                  No          3
# 17                                                  No          3
# 18                                                  No          3
# 19                                                  No          3
# 20                                                  No          2
# 21                                                  No          2
# 22                                                  No          2
# 23                                                  No          2
# 24                                                  No          3
# 25                                                  No          2
# 26                                                  No          2
# 27                                                  No          3
# 28                                                  No          3
# 29                                                  No          3
# ..                                                 ...        ...
# 108                                                 No          3
# 109                                                 No          2
# 110                                                 No          2
# 111                                                 No          1
# 112                                                 No          3
# 113                                                 No          3
# 114                                                 No          3
# 115                                                 No          2
# 116                                                 No          2
# 117                                                 No          2
# 118                                                 No          2
# 119                                                 No          2
# 120                                                 No          3
# 121                                                 No          2
# 122                                                 No          2
# 123                                                 No          3
# 124                                                 No          3
# 125                 Deuteranopes (red-green blindness)          2
# 126                                                 No          1
# 127                                                 No          3
# 128                                                 No          2
# 129                                                 No          3
# 130                                                 No          2
# 131                                                 No          2
# 132                                                 No          3
# 133                                                 No          3
# 134                                                 No          1
# 135                                                 No          2
# 136                                                 No          2
# 137                                                 No          3
#
#                                               vistools scenario1 scenario2  \
# 0                                                  NaN  Option 2  Option 2
# 1                                    Excel, Powerpoint  Option 2  Option 2
# 2                                     Excel, R, MATLAB  Option 2  Option 2
# 3                                                    R  Option 1  Option 1
# 4                                                  NaN  Option 2  Option 2
# 5                              Excel, Powerpoint, SCSS  Option 2  Option 2
# 6                                    Excel, Powerpoint  Option 2  Option 2
# 7                                    Adobe Illustrator  Option 2  Option 2
# 8                    Excel, Powerpoint, Python, MATLAB  Option 2  Option 2
# 9                                           Powerpoint  Option 2  Option 2
# 10                           Excel, Powerpoint, MATLAB  Option 2  Option 2
# 11                                                 NaN  Option 2  Option 2
# 12                                               Excel  Option 2  Option 2
# 13                                                 NaN  Option 2  Option 1
# 14                                                 NaN  Option 2  Option 2
# 15                                   Adobe Illustrator  Option 2  Option 2
# 16                                                 NaN  Option 2  Option 2
# 17                           Excel, Powerpoint, Python  Option 1  Option 2
# 18                                   Excel, Powerpoint  Option 2  Option 2
# 19                                                 NaN  Option 2  Option 2
# 20                                          Powerpoint  Option 2  Option 2
# 21                                          Powerpoint  Option 2  Option 2
# 22   Excel, Powerpoint, Numbers, Pages, GoodNotes4,...  Option 2  Option 2
# 23                                   Excel, Powerpoint  Option 2  Option 2
# 24                                                 NaN  Option 2  Option 2
# 25                                          Powerpoint  Option 2  Option 2
# 26                                                 NaN  Option 2  Option 1
# 27                                          Powerpoint  Option 2  Option 2
# 28                                               Visio  Option 2  Option 2
# 29                        Excel, Python, R, MATLAB, D3  Option 2  Option 2
# ..                                                 ...       ...       ...
# 108                         Powerpoint, Python, MATLAB  Option 2  Option 2
# 109                                                NaN  Option 2  Option 2
# 110                                              Excel  Option 2  Option 2
# 111                                                NaN  Option 2  Option 2
# 112                      Powerpoint, Adobe Illustrator  Option 2  Option 2
# 113                                                NaN  Option 2  Option 2
# 114                                             Python  Option 2  Option 1
# 115                                              Paint  Option 2  Option 2
# 116                                         Powerpoint  Option 2  Option 2
# 117                                  Excel, Powerpoint  Option 2  Option 2
# 118                                  Excel, Powerpoint  Option 2  Option 2
# 119                                  Excel, Powerpoint  Option 2  Option 2
# 120                           Excel, Powerpoint, Canva  Option 2  Option 2
# 121                                         Powerpoint  Option 2  Option 2
# 122                                                NaN  Option 2  Option 1
# 123                          Excel, Powerpoint, Origin  Option 2  Option 2
# 124                                                  R  Option 2  Option 1
# 125                                                NaN  Option 2  Option 2
# 126                                         Powerpoint  Option 2  Option 2
# 127                                 Powerpoint, Python  Option 2  Option 2
# 128                                                NaN  Option 2  Option 2
# 129                                         Powerpoint  Option 2  Option 2
# 130                                                NaN  Option 2  Option 2
# 131                                                NaN  Option 2  Option 2
# 132                              Excel, Graphpad Prism  Option 2  Option 2
# 133                        Excel, Powerpoint, Power BI  Option 2  Option 1
# 134                                         Powerpoint  Option 2  Option 2
# 135                                              Excel  Option 2  Option 2
# 136                                         Powerpoint  Option 2  Option 2
# 137                  Excel, Powerpoint, Python, MATLAB  Option 2  Option 2
#
#     scenario3 scenario4        pie  donut    treemap  bar  stacked   funnel  \
# 0    Option 2  Option 1  17.000000  42.00  18.000000    7    35.00  15.0000
# 1    Option 2  Option 3  28.000000  40.00  42.000000   12    35.00  20.0000
# 26     45.0    50.0  20.000  35.00   15.0  46.000000
# 27     70.0    45.0  33.000  33.00   25.0  50.000000
# 28     70.0    45.0  90.000  35.00   30.0  45.000000
# 29     40.0    30.0  38.000  40.00   25.0  50.000000
# ..      ...     ...     ...    ...    ...        ...
# 108    60.0   135.0  12.500  25.00   25.0  66.666667
# 109   110.0   180.0  15.000  25.00   25.0  40.000000
# 110    70.0   120.0  10.000  18.00   20.0  45.000000
# 111    60.0   120.0  12.500  25.00   33.0  40.000000
# 112    15.0    75.0  15.000  25.00   25.0  40.000000
# 113    90.0   120.0  20.000  35.00   33.0  47.000000
# 114    40.0   110.0   5.000  25.00   75.0  48.000000
# 115    25.0   130.0  15.000  25.00   35.0  50.000000
# 116    45.0   120.0  10.000  30.00   30.0  45.000000
# 117    45.0   120.0  15.000  25.00   33.3  50.000000
# 118    40.0   160.0  10.000  25.00   25.0  50.000000
# 119    70.0   120.0  10.000  20.00   30.0  50.000000
# 120    45.0   120.0  10.000  25.00   25.0  49.000000
# 121    60.0   150.0  10.000  25.00   35.0  50.000000
# 122    80.0   135.0  10.000  25.00   35.0  48.000000
# 123    60.0   120.0  12.500  25.00   33.0  50.000000
# 124    18.0   125.0   9.000  25.00   34.0  48.000000
# 125    60.0   120.0  10.000  25.00   33.0  50.000000
# 126    70.0   135.0  20.000  75.00   33.3  50.000000
# 127    83.0   125.0  14.000  27.00   33.0  45.000000
# 128    35.0   135.0   7.000  25.00   33.0  50.000000
# 129    60.0   135.0  10.000  25.00   35.0  47.000000
# 130    75.0   140.0  10.000  30.00   25.0  48.000000
# 131    50.0   135.0  10.000  25.00   37.0  45.000000
# 132    70.0   120.0  20.000  35.00   35.0  45.000000
# 133    60.0   135.0  15.000  90.00   25.0  50.000000
# 134    60.0   120.0  15.000  30.00   40.0  45.000000
# 135    75.0   135.0   7.500  25.00   30.0  50.000000
# 136    70.0   120.0  10.000  25.00   20.0  40.000000
# 137    70.0   110.0  10.000  30.00   30.0  50.000000
#
#                                               comments  confidence  Block  \
# 0                                                  NaN         3.0      1
# 1                                                  NaN         3.0      1
# 2    I’m seriously interested in these results. The...         3.0      1
# 3    The 15 seconds gave me all the time I needed h...         4.0      1
# 4                                                  NaN         4.0      1
# 5                                                  NaN         4.0      1
# 6                                                  NaN         3.0      1
# 7                                      I love you Evin         4.0      1
# 8                           Really interesting topic!          4.0      1
# 9    For the question on toothbrush sales the figur...         3.0      1
# 10                                                 NaN         3.0      1
# 11   That was class craic! A real workout for the n...         3.0      1
# 12                                                 NaN         4.0      1
# 13             that was hard. clearly explained though         5.0      1
# 14                                                 NaN         4.0      1
# 15                                                 NaN         2.0      1
# 16                                                 NaN         3.0      1
# 17                                                 NaN         2.0      1
# 18                                                 NaN         4.0      1
# 19   This was extremely interesting. I'd love to be...         4.0      1
# 20                                                 NaN         3.0      1
# 21                                                 NaN         4.0      1
# 22                         Fuckn, graphs are hard man          2.0      1
# 23                                                 NaN         3.0      1
# 24                                                 NaN         3.0      1
# 25                                                 NaN         2.0      1
# 26                                                 NaN         3.0      1
# 27                                                 NaN         3.0      1
# 28                                                 NaN         4.0      1
# 29   Interested in your thesis.  Share results when...         3.0      1
# ..                                                 ...         ...    ...
# 108  Difficult to tell the angles/comparisons witho...         3.0      4
# 109                                                NaN         2.0      4
# 110                                                NaN         3.0      4
# 111                                                NaN         2.0      4
# 112                        I’m too dyspraxic for this          1.0      4
# 113                                                NaN         1.0      4
# 114                                                NaN         4.0      4
# 115                                     V interesting!         3.0      4
# 116                                                NaN         3.0      4
# 117                                                NaN         3.0      4
# 118                                                Nah         3.0      4
# 119                                        Good luck!          4.0      4
# 120  That one with the orange and blue circle reall...         2.0      4
# 121                                                NaN         4.0      4
# 122                                                NaN         4.0      4
# 123                               Fun figuring it out!         4.0      4
# 124                                                NaN         4.0      4
# 125                                                NaN         3.0      4
# 126                                                NaN         2.0      4
# 127                                                NaN         4.0      4
# 128                                                NaN         4.0      4
# 129  Nice survey my brother, I hope your thesis goe...         5.0      4
# 130                                                NaN         2.0      4
# 131                                                NaN         3.0      4
# 132                                                NaN         3.0      4
# 133                                                NaN         NaN      4
# 134                                                NaN         4.0      4
# 135                                                NaN         4.0      4
# 136                                                NaN         5.0      4
# 137                                                NaN         3.0      4
#
#      block  pie_tv  donut_tv  treemap_tv  bar_tv  stacked_tv  funnel_tv  \
# 0        1    17.8      38.3        26.1    10.0        38.6       22.2
# 1        1    17.8      38.3        26.1    10.0        38.6       22.2
# 2        1    17.8      38.3        26.1    10.0        38.6       22.2
# 3        1    17.8      38.3        26.1    10.0        38.6       22.2
# 4        1    17.8      38.3        26.1    10.0        38.6       22.2
# 5        1    17.8      38.3        26.1    10.0        38.6       22.2
# 6        1    17.8      38.3        26.1    10.0        38.6       22.2
# 7        1    17.8      38.3        26.1    10.0        38.6       22.2
# 8        1    17.8      38.3        26.1    10.0        38.6       22.2
# 9        1    17.8      38.3        26.1    10.0        38.6       22.2
# 10       1    17.8      38.3        26.1    10.0        38.6       22.2
# 11       1    17.8      38.3        26.1    10.0        38.6       22.2
# 12       1    17.8      38.3        26.1    10.0        38.6       22.2
# 13       1    17.8      38.3        26.1    10.0        38.6       22.2
# 14       1    17.8      38.3        26.1    10.0        38.6       22.2
# 15       1    17.8      38.3        26.1    10.0        38.6       22.2
# 16       1    17.8      38.3        26.1    10.0        38.6       22.2
# 17       1    17.8      38.3        26.1    10.0        38.6       22.2
# 18       1    17.8      38.3        26.1    10.0        38.6       22.2
# 19       1    17.8      38.3        26.1    10.0        38.6       22.2
# 20       1    17.8      38.3        26.1    10.0        38.6       22.2
# 21       1    17.8      38.3        26.1    10.0        38.6       22.2
# 22       1    17.8      38.3        26.1    10.0        38.6       22.2
# 23       1    17.8      38.3        26.1    10.0        38.6       22.2
# 24       1    17.8      38.3        26.1    10.0        38.6       22.2
# 25       1    17.8      38.3        26.1    10.0        38.6       22.2
# 26       1    17.8      38.3        26.1    10.0        38.6       22.2
# 27       1    17.8      38.3        26.1    10.0        38.6       22.2
# 28       1    17.8      38.3        26.1    10.0        38.6       22.2
# 5     0.111111    2.200     1.40       1.9   3.000000    24.144444  Trimmed
# 6     5.444444    0.800     8.60       3.1   3.000000    44.766667     Kept
# 7     4.750000   10.800     5.60       1.9   2.000000    45.750000     Kept
# 8     1.500000    9.200     1.40       1.9   2.000000    26.233333     Kept
# 9     6.000000   10.800     5.60       6.9   2.000000    69.955556     Kept
# 10    5.444444    5.800     1.40       1.9   3.000000    35.188889     Kept
# 11    2.666667    2.500     1.40       1.9   2.000000    55.744444     Kept
# 12    2.666667    4.800    11.60       6.9   0.000000    62.455556     Kept
# 13    1.500000    9.200     5.27       3.1   2.000000   114.762222  Trimmed
# 14    4.055556    1.200    11.60       3.1   3.000000    44.133333     Kept
# 15    1.500000   15.800    13.60       1.9   3.000000    96.133333  Trimmed
# 16    4.055556    8.900     1.40       1.9   2.000000    37.555556     Kept
# 17    4.750000    5.800     8.60      11.9   2.000000    74.550000     Kept
# 18    2.666667    2.200     1.40       1.9   2.000000    27.500000     Kept
# 19    2.666667    0.800     8.60       6.9   2.000000    45.300000     Kept
# 20    4.055556    2.200     3.60       1.9   3.000000    55.555556     Kept
# 21    1.277778    2.800     0.60       3.1   1.000000    70.222222     Kept
# 22    0.111111    0.800     1.10       3.1   2.000000    25.755556  Trimmed
# 23    1.000000    9.200     1.40       1.9   2.000000    35.400000     Kept
# 24    2.666667    2.200     1.40       1.9   2.000000    20.900000  Trimmed
# 25    1.500000    2.536     1.40       1.9   2.000000    22.236000  Trimmed
# 26    2.888889   10.800     3.60      11.9   2.000000    68.288889     Kept
# 27    1.500000    2.200     5.60       1.9   2.000000    43.044444     Kept
# 28    1.500000   59.200     3.60       3.1   3.000000    91.844444  Trimmed
# 29    2.666667    7.200     1.40       1.9   2.000000    48.855556     Kept
# ..         ...      ...      ...       ...        ...          ...      ...
# 108   1.100000    1.500     1.90       5.8  18.666667    40.800000     Kept
# 109  11.400000    4.000     1.90       5.8   8.000000    93.755556  Trimmed
# 110   5.266667    1.000     8.90      10.8   3.000000    46.311111     Kept
# 111   5.266667    1.500     1.90       2.2   8.000000    39.177767     Kept
# 112  17.766667    4.000     1.90       5.8   8.000000    90.200000  Trimmed
# 113   5.266667    9.000     8.10       2.2   1.000000    68.866667     Kept
# 114   8.044444    6.000     1.90      44.2   0.000000    92.133333  Trimmed
# 115   2.488889    4.000     1.90       4.2   2.000000    45.944444     Kept
# 116   5.266667    1.000     3.10       0.8   3.000000    42.166667     Kept
# 117   5.266667    4.000     1.90       2.5   2.000000    42.266667     Kept
# 118   5.844444    1.000     1.90       5.8   2.000000    49.333333     Kept
# 119   5.266667    1.000     6.90       0.8   2.000000    33.711111     Kept
# 120   5.266667    1.000     1.90       5.8   1.000000    81.633333  Trimmed
# 121   3.066667    1.000     1.90       4.2   2.000000    22.200000  Trimmed
# 122   1.100000    1.000     1.90       4.2   0.000000    25.522222  Trimmed
# 123   5.266667    1.500     1.90       2.2   2.000000    22.200000  Trimmed
# 124   3.877778    2.000     1.90       3.2   0.000000    64.977778     Kept
# 125   5.266667    1.000     1.90       2.2   2.000000    30.800000     Kept
# 126   1.100000    9.000    48.10       2.5   2.000000    74.244444     Kept
# 127   3.877778    3.000     0.10       2.2   3.000000    60.933333     Kept
# 128   1.100000    4.000     1.90       2.2   2.000000    37.577778     Kept
# 129   1.100000    1.000     1.90       4.2   1.000000    32.433333     Kept
# 130   0.288889    1.000     3.10       5.8   0.000000    26.822222     Kept
# 131   1.100000    1.000     1.90       6.2   3.000000    26.011111  Trimmed
# 132   5.266667    9.000     8.10       4.2   3.000000    70.511111     Kept
# 133   1.100000    4.000    63.10       5.8   2.000000   136.833333  Trimmed
# 134   5.266667    4.000     3.10       9.2   3.000000    50.200000     Kept
# 135   1.100000    3.500     1.90       0.8   2.000000    24.063333  Trimmed
# 136   5.266667    1.000     1.90      10.8   8.000000    48.511111     Kept
# 137   8.044444    1.000     3.10       0.8   2.000000    86.348889  Trimmed
#
# [138 rows x 55 columns]

# %%
g =sns.violinplot(x="gender", y="confidence", data=df, dodge=False)
plt.xticks(rotation=60)
sns.despine()
plt.ylim(ymax=5.5, ymin=0.5)
g.set(xlabel='Gender', ylabel='Confidence')

plt.savefig('../output/03Bgenderconfidence.png', dpi = 300)

# %% [markdown]
# ### 3.C. Scenario Selection

# %%
sns.set_context("notebook")
g = sns.countplot('scenario1', data=df, order=['Option 1', 'Option 2'])
g.set(xlabel='Scenario 1', ylabel='Number of Participants')
sns.despine(right=True, left=True)

plt.savefig('../output/03Cscenario1.png', dpi = 300)

# df or tdf?

# %%
g = sns.countplot('scenario2', data=df, order=['Option 1', 'Option 2'])
g.set(xlabel='Scenario 2', ylabel='Number of Participants')
sns.despine(right=True, left=True)

plt.savefig('../output/03Cscenario2.png', dpi = 300)

# %%
g = sns.countplot('scenario3', data=tdf, order=['Option 1', 'Option 2'])
g.set(xlabel='Scenario 3', ylabel='Number of Participants')
sns.despine(right=True, left=True)

plt.savefig('../output/03Cscenario3.png', dpi = 300)

# %%
g = sns.countplot('scenario4', data=tdf, order=['Option 1', 'Option 2', 'Option 3', 'Option 4'])
g.set(xlabel='Scenario 4', ylabel='Number of Participants')
sns.despine(right=True, left=True)


plt.savefig('../output/03Cscenario4.png', dpi = 300)

# %% [markdown]
# ### 3.D. Investigate how each graph performed

# %%
plotdata = df_long[df_long['charttype'].isin(['pie','donut', 'treemap', 'bar', 'stacked', 'funnel'])]

plt.figure(figsize=(15, 5))
g= sns.violinplot(x="charttype", y="error", data=plotdata)
g = sns.swarmplot(x="charttype", y="error", data=plotdata, alpha=0.3, color ='k')

g.set(title='Error across traditional charts', ylabel='Absolute Error in percentage points', xlabel='Chart Type')
sns.despine(left=True)
plt.gcf().subplots_adjust(left=0.25)
plt.ylim(ymin=0)

plt.savefig('../output/03Dcharttypetrad.png', dpi = 300)

# %% [markdown]
# Let's take a closer look at the means and interquartile ranges, and remove the swarmplot for clarity

# %%
plotdata = df_long[df_long['charttype'].isin(['pie','donut', 'treemap', 'bar', 'stacked', 'funnel'])]

plt.figure(figsize=(15, 5))
g= sns.violinplot(x="charttype", y="error", data=plotdata)
g = sns.swarmplot(x="charttype", y="error", data=plotdata, alpha=0.3, color ='k')

g.set(title='Error across traditional charts', ylabel='Absolute Error in percentage points', xlabel='Chart Type')
sns.despine(left=True)
plt.gcf().subplots_adjust(left=0.25)
plt.ylim(ymin=0)

plt.savefig('../output/03Dcharttypetrad.png', dpi = 300)

# %% [markdown]
# Looking at the arc, angle and area charts

# %%
plotdata = df_long[df_long['charttype'].isin(['pie','donut','arc','angle','area'])]

plt.figure(figsize=(15, 5))
g= sns.violinplot(x="charttype", y="error", data=plotdata)
g = sns.swarmplot(x="charttype", y="error", data=plotdata, color='k', alpha=.3)

g.set(title='Error across pie decomposition charts', xlabel='Chart Type', ylabel='Absolute Percentage Points Error')
sns.despine(left=True)
plt.gcf().subplots_adjust(left=0.25)
plt.ylim(ymin=0)
plt.savefig('../output/03Dcharttypeaaa.png', dpi = 300)

# %% [markdown]
# Let's take a closer look at the means and interquartile ranges, and remove the swarmplot for clarity

# %%
plotdata = df_long[df_long['charttype'].isin(['pie','donut','arc','angle','area'])]

plt.figure(figsize=(15, 5))
g= sns.violinplot(x="charttype", y="error", data=plotdata)

g.set(title='Error across pie decomposition charts', xlabel='Chart Type', ylabel='Absolute Percentage Points Error')
sns.despine(left=True)
plt.gcf().subplots_adjust(left=0.25)
plt.ylim(ymin=0, ymax=4)
plt.savefig('../output/03Dcharttypeaaa.png', dpi = 300)

# %% [markdown]
# ### 3.E. Pie Charts

# %%
df1 = df_long.pivot(columns='charttype', values='error').mean()
df2 = df_long.pivot(columns='charttype', values='error').std()
summaryStats = pd.concat([df1, df2], axis=1)

summaryStats.to_csv('summaryStats.csv')

# %%
df_long.pivot(columns='charttype', values='error').describe()
# Out:
# charttype       angle         arc        area         bar       donut  \
# count      203.000000  203.000000  204.000000  102.000000  101.000000
# mean         3.179666    3.514286    3.543954    3.550980    3.061386
# std          3.016338    3.038294    2.942933    3.059857    4.144658
# min          0.055556    0.000000    0.000000    0.000000    0.000000
# 25%          0.988889    1.650000    1.800000    2.000000    0.300000
# 50%          2.488889    2.200000    2.200000    2.800000    1.700000
# 75%          5.266667    4.000000    4.200000    5.000000    3.700000
# max         17.766667   20.000000   18.666667   16.600000   22.700000
#
# charttype      funnel         pie     stacked    treemap
# count      100.000000  100.000000  102.000000  98.000000
# mean         3.842111    3.619667    3.767647   5.451327
# std          2.645685    4.594327    3.966298   5.539592
# min          0.200000    0.300000    0.000000   0.000000
# 25%          2.200000    1.400000    1.100000   1.400000
# 50%          3.900000    2.200000    2.000000   3.600000
# 75%          5.300000    2.800000    5.300000   6.400000
# max         12.300000   24.700000   21.300000  24.400000

# %% [markdown]
# # End of main experiment

# %% [markdown]
# ## Journal Survey

# %%
journalSurvey = pd.melt(pd.read_csv('journalSurvey.csv'),id_vars='chartType', value_vars=['2006','2016'], var_name='year')

g = sns.factorplot(x = 'value', y='chartType', hue='year', data=journalSurvey, kind = 'bar', size=7, aspect=1,legend_out=False)
g.fig.axes[0].invert_yaxis()
g.ax.legend(loc=5)
sns.despine()
g.set(title='Journal Survey Results', xlabel='Frequency', ylabel='Chart Type')

plt.savefig('../output/99journalSurvey.png', dpi = 300)

# %% [markdown]
# ## Anscombe's Quartet

# %%
# Load the example dataset for Anscombe's quartet
df_anscombe = sns.load_dataset("anscombe")

# Show the results of a linear regression within each dataset
sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=df_anscombe,
           col_wrap=2, ci=None, size=4,
           scatter_kws={"s": 50, "alpha": 1})

plt.savefig('../output/99Anscombe.png', dpi = 300)

# %% [markdown]
# ### R.W.C.

# %%
df.age[pd.notnull(df.age)];

# %% [markdown]
# x = df.age[pd.notnull(df.age)]
# sns.kdeplot(x, shade=True);

# %% [markdown]
# x = census_agesex['Age']
# sns.kdeplot(x);
# plt.xlim(0, 95)

# %%
pal = sns.color_palette('deep')
pal.as_hex()
#ax.set(xlabel='common xlabel', ylabel='common ylabel')
# Out:
# ['#4c72b0', '#55a868', '#c44e52', '#8172b2', '#ccb974', '#64b5cd']

# %%
#This was the missing element for so long!

df_long[df_long['charttype'].isin(['pie','donut'])];

# %%
# Make the PairGrid
g = sns.PairGrid(tdf.sort_values("Total_Error", ascending=False),
                 x_vars=tdf.columns[-15:-9], y_vars=["timestamp"],
                 size=10, aspect=.25)

# Draw a dot plot using the stripplot function
g.map(sns.stripplot, size=10, orient="h",
      palette="Reds_r", edgecolor="gray")

# Use the same x axis limits on all columns and add better labels
g.set(xlim=(-10, 10), ylabel="")

# Use semantically meaningful titles for the columns
titles = ["Pie", "Donut","Treemap", "Bar", "Stacked", "Funnel"]

for ax, title in zip(g.axes.flat, titles):

    #Set a different title for each axes
    ax.set(title=title)

    # Make the grid horizontal instead of vertical
    ax.xaxis.grid(False)
    ax.yaxis.grid(True)
    ax.set(xticklabels='')
    ax.set(yticklabels='')

sns.despine(left=True, bottom=True)

plt.savefig('../output/99Extra.png', dpi = 300)

# %%
tradCharts = ['pie','donut','treemap','bar','stacked','funnel']
aaaCharts = ['angle1', 'angle2', 'arc1', 'arc2', 'area1', 'area2']

# subset selection of users who have made visualisation recently
# len(tdf[pd.notnull(tdf['vistools'])])
#print(comments)

# %%
# Combine this array and combine the different samples for angle, arc and area
plotdata = df_long[df_long['charttype'].isin(['pie','donut', 'angle1', 'angle2', 'arc1', 'arc2', 'area1', 'area2'])]

plotdata.loc[plotdata['charttype'] == 'angle1', 'charttype']  = 'angle'
plotdata.loc[plotdata['charttype'] == 'angle2', 'charttype']  = 'angle'
plotdata.loc[plotdata['charttype'] == 'arc1', 'charttype']  = 'arc'
plotdata.loc[plotdata['charttype'] == 'arc2', 'charttype']  = 'arc'
plotdata.loc[plotdata['charttype'] == 'area1', 'charttype']  = 'area'
plotdata.loc[plotdata['charttype'] == 'area2', 'charttype']  = 'area'

plt.figure(figsize=(5, 10))
sns.violinplot(x='error',
              y='charttype',
               hue = 'Block',
              data=plotdata, linewidth=1)
sns.despine()
plt.plot([0, 0], [-5, 5], linestyle=':', color='k', linewidth=1)

plt.savefig('../output/06chartsAAA.png', dpi = 300)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
